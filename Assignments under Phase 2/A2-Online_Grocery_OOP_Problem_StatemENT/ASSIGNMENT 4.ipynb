# %% [markdown]
# # Creating Customer Class

# %%
class Customer:
    def __init__(self, name, phone, city, wallet_balance):
        self.name = name
        self.phone = phone
        self.city = city

        # Private variable
        self.__wallet_balance = wallet_balance

    def display_customer_details(self):
        print("\nCustomer Details")
        print("Customer Name:", self.name)
        print("Phone:", self.phone)
        print("City:", self.city)
        print("Wallet Balance:", self.__wallet_balance)

    def get_wallet_balance(self):
        return self.__wallet_balance

    def pay_from_wallet(self, amount):
        if amount <= 0:
            return False
        if amount <= self.__wallet_balance:
            self.__wallet_balance -= amount
            return True
        else:
            return False
    def get_discount_percentage(self):
        return 0

# %% [markdown]
# # Premium Customer Class

# %%
class PremiumCustomer(Customer):
    def __init__(self, name, phone, city, wallet_balance, membership_id):
        super().__init__(name, phone, city, wallet_balance)
        self.membership_id = membership_id

    def display_customer_details(self):
        super().display_customer_details()
        print("Membership ID:", self.membership_id)

    def get_discount_percentage(self):
        return 10

# %% [markdown]
# # Grocery Item Class

# %%
class GroceryItem:

    def __init__(self, item_name, category, price, stock_quantity):
        self.item_name = item_name
        self.category = category
        self.__price = price
        self.__stock_quantity = stock_quantity

    def display_item_details(self):
        print("\nItem Details")
        print("Item Name:", self.item_name)
        print("Category:", self.category)
        print("Price:", self.__price)
        print("Available Stock:", self.__stock_quantity)

    def get_price(self):
        return self.__price
    def get_stock_quantity(self):
        return self.__stock_quantity
    def reduce_stock(self, quantity):
        if quantity <= 0:
            return False
        if quantity <= self.__stock_quantity:
            self.__stock_quantity -= quantity
            return True
        else:
            return False

# %% [markdown]
# # Order Class

# %%
class Order:
    def __init__(self, customer, grocery_item, quantity):
        self.customer = customer
        self.grocery_item = grocery_item
        self.quantity = quantity
        self.total_amount = 0
        self.discount_amount = 0
        self.final_amount = 0
        self.order_status = "Pending"

    def place_order(self):
        if self.quantity <= 0:
            self.order_status = "Failed - Invalid Quantity"
            return
        if self.quantity > self.grocery_item.get_stock_quantity():
            self.order_status = "Failed - Stock Not Available"
            return
        self.total_amount = (self.grocery_item.get_price() * self.quantity)

        discount_percentage = (self.customer.get_discount_percentage())

        self.discount_amount = (self.total_amount * discount_percentage / 100)

        self.final_amount = (self.total_amount - self.discount_amount)

        payment_success = (self.customer.pay_from_wallet(self.final_amount))

        if payment_success:
            self.grocery_item.reduce_stock(self.quantity)
            self.order_status = "Order Placed"
        else:
            self.order_status = "Failed - Payment Failed"

    def display_order_details(self):
        print("\nOrder Details")
        print("Customer Name:", self.customer.name)
        print("Item Name:", self.grocery_item.item_name)
        print("Quantity:", self.quantity)
        print("Total Amount:", self.total_amount)
        print("Discount Amount:", self.discount_amount)
        print("Final Amount:", self.final_amount)
        print("Order Status:", self.order_status)

# %% [markdown]
# # Creating Customer Objects

# %%
customer1 = Customer("Ravi","111222333","Chennai",1000)
customer2 = PremiumCustomer("Priya","444555666","Mumbai",1000,"PRM101")
customer3 = Customer("Arjun","777888999","Delhi",100)
customer4 = Customer("Meena","101010101","Pune",2000)
customer5 = Customer("Kumar","121212121","Lucknow",1000)

# %% [markdown]
# # Createing Grocery Items

# %%
item_rice = GroceryItem("Rice","Grains",60,20)
item_oil = GroceryItem("Oil","Cooking",200,10)
item_sugar = GroceryItem("Sugar","Sweetener",80,10)
item_milk = GroceryItem("Milk","Dairy",30,5)
item_wheat = GroceryItem("Wheat","Grains",50,20)

# %% [markdown]
# # Test Case 1: Successful Normal Customer Order

# %%
customer1.display_customer_details()
item_rice.display_item_details()
order1 = Order(customer1, item_rice, 5)
order1.place_order()
order1.display_order_details()
item_rice.display_item_details()
# Out:
# Customer Details
# Customer Name: Ravi
# Phone: 111222333
# City: Chennai
# Wallet Balance: 700.0
#
# Item Details
# Item Name: Rice
# Category: Grains
# Price: 60
# Available Stock: 15
#
# Order Details
# Customer Name: Ravi
# Item Name: Rice
# Quantity: 5
# Total Amount: 300
# Discount Amount: 0.0
# Final Amount: 300.0
# Order Status: Order Placed
#
# Item Details
# Item Name: Rice
# Category: Grains
# Price: 60
# Available Stock: 10

# %% [markdown]
# # Test Case 2 :Successful Premium Customer Order

# %%
customer2.display_customer_details()
item_oil.display_item_details()
order2 = Order(customer2, item_oil, 2)
order2.place_order()
order2.display_order_details()
item_oil.display_item_details()
# Out:
# Customer Details
# Customer Name: Priya
# Phone: 444555666
# City: Mumbai
# Wallet Balance: 1000
# Membership ID: PRM101
#
# Item Details
# Item Name: Oil
# Category: Cooking
# Price: 200
# Available Stock: 10
#
# Order Details
# Customer Name: Priya
# Item Name: Oil
# Quantity: 2
# Total Amount: 400
# Discount Amount: 40.0
# Final Amount: 360.0
# Order Status: Order Placed
#
# Item Details
# Item Name: Oil
# Category: Cooking
# Price: 200
# Available Stock: 8

# %% [markdown]
# # Test Case 3: Failed Order Due To Low Wallet Balance

# %%
customer3.display_customer_details()
item_sugar.display_item_details()
order3 = Order(customer3, item_sugar, 3)
order3.place_order()
order3.display_order_details()
item_sugar.display_item_details()
# Out:
# Customer Details
# Customer Name: Arjun
# Phone: 777888999
# City: Delhi
# Wallet Balance: 100
#
# Item Details
# Item Name: Sugar
# Category: Sweetener
# Price: 80
# Available Stock: 10
#
# Order Details
# Customer Name: Arjun
# Item Name: Sugar
# Quantity: 3
# Total Amount: 240
# Discount Amount: 0.0
# Final Amount: 240.0
# Order Status: Failed - Payment Failed
#
# Item Details
# Item Name: Sugar
# Category: Sweetener
# Price: 80
# Available Stock: 10

# %% [markdown]
# # Test Case 4: Failed Order Due To Stock Not Available

# %%
customer4.display_customer_details()
item_milk.display_item_details()
order4 = Order(customer4, item_milk, 10)
order4.place_order()
order4.display_order_details()
item_milk.display_item_details()
# Out:
# Customer Details
# Customer Name: Meena
# Phone: 101010101
# City: Pune
# Wallet Balance: 2000
#
# Item Details
# Item Name: Milk
# Category: Dairy
# Price: 30
# Available Stock: 5
#
# Order Details
# Customer Name: Meena
# Item Name: Milk
# Quantity: 10
# Total Amount: 0
# Discount Amount: 0
# Final Amount: 0
# Order Status: Failed - Stock Not Available
#
# Item Details
# Item Name: Milk
# Category: Dairy
# Price: 30
# Available Stock: 5

# %% [markdown]
# # Test Case 5:Failed Order Due To Invalid Quantity

# %%
customer5.display_customer_details()
item_wheat.display_item_details()
order5 = Order(customer5, item_wheat, 0)
order5.place_order()
order5.display_order_details()
item_wheat.display_item_details()
# Out:
# Customer Details
# Customer Name: Kumar
# Phone: 121212121
# City: Lucknow
# Wallet Balance: 1000
#
# Item Details
# Item Name: Wheat
# Category: Grains
# Price: 50
# Available Stock: 20
#
# Order Details
# Customer Name: Kumar
# Item Name: Wheat
# Quantity: 0
# Total Amount: 0
# Discount Amount: 0
# Final Amount: 0
# Order Status: Failed - Invalid Quantity
#
# Item Details
# Item Name: Wheat
# Category: Grains
# Price: 50
# Available Stock: 20
